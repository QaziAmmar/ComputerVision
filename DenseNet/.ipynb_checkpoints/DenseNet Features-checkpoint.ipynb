# %%
import numpy as np
import os
import cv2
from keras.optimizers import SGD
import keras.backend as K
import scipy.io as sio
from keras.models import Model
from densenet121 import DenseNet
import glob
import pickle
# Out:
# Using TensorFlow backend.

# %%
weights_path = 'densenet121_weights_tf.h5'
model = DenseNet(reduction=0.5, classes=1000, weights_path=weights_path)
# Out:
# hiiii
# E:\ITU\Dr_Mohsen\houseCounting\FusionNet_surveyAuto\DenseNet\densenet121.py:47: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (7, 7), name="conv1", strides=(2, 2), use_bias=False)`
#   x = Convolution2D(nb_filter, 7, 7, subsample=(2, 2), name='conv1', bias=False)(x)
# E:\ITU\Dr_Mohsen\houseCounting\FusionNet_surveyAuto\DenseNet\densenet121.py:101: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv2_1_x1", use_bias=False)`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# E:\ITU\Dr_Mohsen\houseCounting\FusionNet_surveyAuto\DenseNet\densenet121.py:111: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), name="conv2_1_x2", use_bias=False)`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-163a77456bf7> in <module>()
#       1 weights_path = 'densenet121_weights_tf.h5'
# ----> 2 model = DenseNet(reduction=0.5, classes=1000, weights_path=weights_path)
#
# E:\ITU\Dr_Mohsen\houseCounting\FusionNet_surveyAuto\DenseNet\densenet121.py in DenseNet(nb_dense_block, growth_rate, nb_filter, reduction, dropout_rate, weight_decay, classes, weights_path)
#      55     for block_idx in range(nb_dense_block - 1):
#      56         stage = block_idx+2
# ---> 57         x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)
#      58
#      59         # Add transition_block
#
# E:\ITU\Dr_Mohsen\houseCounting\FusionNet_surveyAuto\DenseNet\densenet121.py in dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate, weight_decay, grow_nb_filters)
#     165         branch = i+1
#     166         x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
# --> 167         concat_feat = merge([concat_feat, x], mode='concat', concat_axis=concat_axis, name='concat_'+str(stage)+'_'+str(branch))
#     168
#     169         if grow_nb_filters:
#
# TypeError: 'module' object is not callable

# %%
part_model = Model(inputs=model.input, outputs=model.get_layer('relu5_blk').output)
sgd = SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
part_model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
root_path = '/home/surveyauto/SS-Net/Map Downloader/Model Town/'
features_path = root_path + 'Features/DenseNet/'
images_path = root_path + 'Patches/'
locations = open(root_path + 'patches_locations.txt', 'r').read().split('\n')
locations = [row.split(' ') for row in locations]
image_extension = '.png'

# %%
image_height = 256
image_width = 256

for row in locations:
    image = cv2.imread(images_path + row[0] + image_extension)
    test_image = np.zeros((1, image_height, image_width, 3))
    test_image[0, :, :, :] = image
    feature_map = part_model.predict(test_image)
    filename = "{}/{}.npy".format(features_path, row[0])
    np.save(open(filename, 'wb'), feature_map)
